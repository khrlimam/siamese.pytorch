# %%
# import torch
# import torch.nn as nn
# from siamese_dataset_example import SiamesePairDataset as SiameseDataset
# import PIL
# import numpy as np
# from torchvision import datasets
# from torchvision import transforms
# import matplotlib.pyplot as plt
import pandas
from models.siamese_resnet import SiameseResnet
import torch
from torch import nn
import torchvision.transforms as transforms
import pathlib
from torch.utils import data
from siamese_dataset_example import SiamesePairDataset
import PIL.Image as Image
import random
import matplotlib.pyplot as plt
import pathlib

# %%
trfm_valid = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

trfm_train = transforms.Compose([
    transforms.RandomRotation(30),
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

target_trfrm = transforms.Compose([
    lambda x: [x],
    torch.Tensor
])

trfm_valid1 = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor()
])

trfm_train1 = transforms.Compose([
    transforms.RandomRotation(30),
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor()
])

# %%
files = list(pathlib.Path(train_path).glob('*/*.[jJpP]*'))

# %%
train_path = 'dataset/train/facescrub'
valid_path = 'dataset/valid/facescrub'
BATCH_SIZE = 256
trainset = SiamesePairDataset(root=train_path, ext='', transform=trfm_train, target_transform=target_trfrm, glob_pattern='*/*.[jJpP]*')
validset = SiamesePairDataset(root=valid_path, ext='', transform=trfm_valid, target_transform=target_trfrm, glob_pattern='*/*.[jJpP]*')
trainloader = data.DataLoader(trainset, batch_size=BATCH_SIZE, shuffle=True)
validloader = data.DataLoader(validset, batch_size=BATCH_SIZE, shuffle=True)
# Out:
# generating similar pair from	 dataset/train/facescrub: 100%|██████████| 98/98 [00:01<00:00, 60.66it/s]
# generating different pair from	 dataset/train/facescrub: 100%|██████████| 7679514/7679514 [00:53<00:00, 142456.97it/s]
# generating similar pair from	 dataset/valid/facescrub: 100%|██████████| 98/98 [00:00<00:00, 354.61it/s]
# generating different pair from	 dataset/valid/facescrub: 100%|██████████| 1356375/1356375 [00:08<00:00, 167882.74it/s]

# %%
trainset1 = SiamesePairDataset(root=train_path, ext='', transform=trfm_train1, target_transform=target_trfrm, glob_pattern='*/*.[jJpP]*')
validset1 = SiamesePairDataset(root=valid_path, ext='', transform=trfm_valid1, target_transform=target_trfrm, glob_pattern='*/*.[jJpP]*')
trainloader1 = data.DataLoader(trainset, batch_size=BATCH_SIZE, shuffle=True)
validloader1 = data.DataLoader(validset, batch_size=BATCH_SIZE, shuffle=True)
# Out:
# generating similar pair from	 dataset/train/facescrub: 100%|██████████| 98/98 [00:01<00:00, 71.84it/s]
# generating different pair from	 dataset/train/facescrub: 100%|██████████| 7679514/7679514 [00:53<00:00, 144681.51it/s]
# generating similar pair from	 dataset/valid/facescrub: 100%|██████████| 98/98 [00:00<00:00, 176.89it/s]
# generating different pair from	 dataset/valid/facescrub: 100%|██████████| 1356375/1356375 [00:08<00:00, 160488.10it/s]

# %%
toPil = transforms.ToPILImage()

# %%
(a,b), s = random.choice(trainset)
plt.subplot(1,2,1)
plt.title(f"Similarity {s.item()}")
plt.imshow(a.permute(1,2,0))
plt.subplot(1,2,2)
plt.imshow(b.permute(1,2,0))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
